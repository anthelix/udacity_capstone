# %% [markdown]
# Data Engineering Capstone Project
# # Datasets Raw Exploration

# %%
# !sh ../bootstrap_jupyter.sh
# Out:
# + sudo apt-get update -y
# Get:1 http://archive.ubuntu.com/ubuntu bionic InRelease [242 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:5 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/main amd64 Packages [1,344 kB]
# Get:3 http://repos.mesosphere.com/ubuntu xenial InRelease [5,275 B]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 Packages [186 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/universe amd64 Packages [11.3 MB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/restricted amd64 Packages [13.5 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [73.6 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [1,385 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [1,226 kB]
# ...

# %%
import os
import sys
import datetime
import numpy as np
import pandas as pd
path = '../../data/'
pd.set_option('display.max_columns', None)

# %%
list_filename= ['I94_SAS_Labels_Descriptions.SAS', 'immigration_data_sample.csv', 
                "GlobalLandTemperaturesByCity.csv", 'wikipedia-iso-country-codes.csv',
                "airports-extended.csv","airport-codes_csv.csv", 'us-cities-demographics.csv',
               'WDIData.csv', "education-statistics/EdStatsData.csv"]

# %%
def sum1forline(list_filename):
    my_sum = 0
    path = '../../data/'
    for filename in list_filename:
        with open(path+filename) as f:
            a = sum(1 for line in f)
            print("{} rows in {} .".format(a, filename))
            my_sum+=a
            
    return("Total of the files : {:,}".format(my_sum))

# %%
sum1forline(list_filename)
# Out:
# 1100 rows in I94_SAS_Labels_Descriptions.SAS .
# 1001 rows in immigration_data_sample.csv .
# 8599213 rows in GlobalLandTemperaturesByCity.csv .
# 247 rows in wikipedia-iso-country-codes.csv .
# 10668 rows in airports-extended.csv .
# 55076 rows in airport-codes_csv.csv .
# 2892 rows in us-cities-demographics.csv .
# 422137 rows in WDIData.csv .
# 886931 rows in education-statistics/EdStatsData.csv .
# 'Total of the files : 9,979,265'

# %% [markdown]
# ## I94 Immigration Data
#
# * immigration_data_sample.csv
# * There are 1000 rows and 29 columns in *immigration_data_sample.csv*.
# * df_immigration

# %%
file = "immigration_data_sample.csv"
df = pd.read_csv(path+file, sep=",")
nRow, nCol = df.shape
print("There are {} rows and {} columns in  *{}*. ".format(nRow, nCol, file))
display(df.dropna(subset=["insnum"]).head(2))
tab_info=pd.DataFrame(df.dtypes).T.rename(index={0:'column type'})
tab_info=tab_info.append(pd.DataFrame(df.isnull().sum()).T.rename(index={0:'null values (nb)'}))
tab_info=tab_info.append(pd.DataFrame(df.isnull().sum()/df.shape[0]*100)
                         .T.rename(index={0:'null values (%)'}))
display(tab_info)
#change subset

#display(df[pd.notnull(df).any(axis=1)].head(2))
# Out:
# There are 1000 rows and 29 columns in  *immigration_data_sample.csv*.
#     Unnamed: 0      cicid   i94yr  i94mon  i94cit  i94res i94port  arrdate  \
# 15     2938436  5960799.0  2016.0     4.0   245.0   245.0     SAI  20545.0
# 35     3020206  6055103.0  2016.0     4.0   252.0   209.0     AGA  20572.0
#
#     i94mode i94addr  depdate  i94bir  i94visa  count  dtadfile visapost occup  \
# 15      1.0     NaN  20550.0    30.0      2.0    1.0  20160615      NaN   NaN
# 35      1.0      GU  20577.0    27.0      2.0    1.0  20160801      NaN   NaN
#
#    entdepa entdepd  entdepu matflag  biryear   dtaddto gender  insnum airline  \
# 15       P       D      NaN       M   1986.0  04132016      M  3882.0      MU
# 35       A       D      NaN       M   1989.0  06112016      M  3943.0      TW
#
#           admnum  fltno visatype
# 15  4.416258e+10  00763       CP
# 35  5.109649e+10  00311      GMT
#                  Unnamed: 0    cicid    i94yr   i94mon   i94cit   i94res  \
# ...

# %% [markdown]
# ## Global Land Temperature Data
# * GlobalLandTemperaturesByCity.csv
# * There are 8599212 rows and 7 columns in  *GlobalLandTemperaturesByCity.csv*.
# * df_temperature

# %%
file = "GlobalLandTemperaturesByCity.csv"
df = pd.read_csv(path+file, sep=",", nrows=9000000)
nRow, nCol = df.shape
print("There are {} rows and {} columns in  *{}*. ".format(nRow, nCol, file))

display(df.head(2))
tab_info=pd.DataFrame(df.dtypes).T.rename(index={0:'column type'})
tab_info=tab_info.append(pd.DataFrame(df.isnull().sum()).T.rename(index={0:'null values (nb)'}))
tab_info=tab_info.append(pd.DataFrame(df.isnull().sum()/df.shape[0]*100)
                         .T.rename(index={0:'null values (%)'}))
tab_info
#change subset
#df.dropna(subset=["insnum"]).head(2)
# Out:
# There are 8599212 rows and 7 columns in  *GlobalLandTemperaturesByCity.csv*.
#            dt  AverageTemperature  AverageTemperatureUncertainty   City  \
# 0  1743-11-01               6.068                          1.737  Århus
# 1  1743-12-01                 NaN                            NaN  Århus
#
#    Country Latitude Longitude
# 0  Denmark   57.05N    10.33E
# 1  Denmark   57.05N    10.33E
#                       dt AverageTemperature AverageTemperatureUncertainty  \
# column type       object            float64                       float64
# null values (nb)       0             364130                        364130
# null values (%)        0            4.23446                       4.23446
#
#                     City Country Latitude Longitude
# column type       object  object   object    object
# null values (nb)       0       0        0         0
# null values (%)        0       0        0         0

# %% [markdown]
# ## Airports Code Data
# * airport-codes_csv.csv
# * There are 55075 rows and 12 columns in  *airport-codes_csv.csv*.
# * df_airport_code

# %%
file = "airport-codes_csv.csv"
df = pd.read_csv(path+file, sep=",", nrows=9000000)
nRow, nCol = df.shape
print("There are {} rows and {} columns in  *{}*. ".format(nRow, nCol, file))
#display(df[pd.notnull(df).any(axis=1)].head(2))
#display(df.head(2))
display(df.dropna(subset=["iata_code"]).head(2))
tab_info=pd.DataFrame(df.dtypes).T.rename(index={0:'column type'})
tab_info=tab_info.append(pd.DataFrame(df.isnull().sum()).T.rename(index={0:'null values (nb)'}))
tab_info=tab_info.append(pd.DataFrame(df.isnull().sum()/df.shape[0]*100)
                         .T.rename(index={0:'null values (%)'}))
tab_info
#change subse
# Out:
# There are 55075 rows and 12 columns in  *airport-codes_csv.csv*.
#     ident           type                     name  elevation_ft continent  \
# 223   03N  small_airport           Utirik Airport           4.0        OC
# 440  07FA  small_airport  Ocean Reef Club Airport           8.0       NaN
#
#     iso_country iso_region   municipality gps_code iata_code local_code  \
# 223          MH     MH-UTI  Utirik Island     K03N       UTK        03N
# 440          US      US-FL      Key Largo     07FA       OCA       07FA
#
#                            coordinates
# 223                 169.852005, 11.222
# 440  -80.274803161621, 25.325399398804
#                    ident    type    name elevation_ft continent iso_country  \
# column type       object  object  object      float64    object      object
# null values (nb)       0       0       0         7006     27719         247
# null values (%)        0       0       0      12.7208   50.3296    0.448479
#
# ...

# %% [markdown]
# ## Global Airports Data
# * airports-extended.csv
# * There are 10668 rows and 13 columns in  *airports-extended.csv*.
# * df_global_airports

# %%
file = "airports-extended.csv"
df = pd.read_csv(path+file, 
                 header = None, 
                 index_col=0,
                 names=['id', 'name', 'city', 'country', 'iata', 'icao', 'latitude', 'longitude', 'altitude', 
                            'timezone', 'dst', 'tz_timezone', 'type', 'data_source']).rename(columns=lambda col: col)

nRow, nCol = df.shape
print("There are {} rows and {} columns in  *{}*. ".format(nRow, nCol, file))
#display(df[pd.notnull(df).any(axis=1)].head(2))
display(df.head(2))
tab_info=pd.DataFrame(df.dtypes).T.rename(index={0:'column type'})
tab_info=tab_info.append(pd.DataFrame(df.isnull().sum()).T.rename(index={0:'null values (nb)'}))
tab_info=tab_info.append(pd.DataFrame(df.isnull().sum()/df.shape[0]*100)
                         .T.rename(index={0:'null values (%)'}))
tab_info
#change subset
#df.dropna(subset=["insnum"]).head(2)
# Out:
# There are 10668 rows and 13 columns in  *airports-extended.csv*.
#               name    city           country iata  icao  latitude   longitude  \
# id
# 1   Goroka Airport  Goroka  Papua New Guinea  GKA  AYGA  -6.08169  145.391998
# 2   Madang Airport  Madang  Papua New Guinea  MAG  AYMD  -5.20708  145.789001
#
#     altitude timezone dst           tz_timezone     type  data_source
# id
# 1       5282       10   U  Pacific/Port_Moresby  airport  OurAirports
# 2         20       10   U  Pacific/Port_Moresby  airport  OurAirports
#                     name     city country       iata        icao latitude  \
# column type       object   object  object     object      object  float64
# null values (nb)       0       47       0          2           1        0
# null values (%)        0  0.44057       0  0.0187477  0.00937383        0
#
#                  longitude altitude timezone     dst tz_timezone    type  \
# column type        float64    int64   object  object      object  object
# ...

# %% [markdown]
# ## Iso Country Data
# * wikipedia-iso-country-codes.csv
# * There are 246 rows and 4 columns in  *wikipedia-iso-country-codes.csv*.
# * df_iso_country

# %%
file = "wikipedia-iso-country-codes.csv"
df = pd.read_csv(path+file, sep=",", nrows=9000000)
nRow, nCol = df.shape
print("There are {} rows and {} columns in  *{}*. ".format(nRow, nCol, file))
#display(df[pd.notnull(df).any(axis=1)].head(2))
display(df.head(2))
tab_info=pd.DataFrame(df.dtypes).T.rename(index={0:'column type'})
tab_info=tab_info.append(pd.DataFrame(df.isnull().sum()).T.rename(index={0:'null values (nb)'}))
tab_info=tab_info.append(pd.DataFrame(df.isnull().sum()/df.shape[0]*100)
                         .T.rename(index={0:'null values (%)'}))
tab_info
#change subset
#df.dropna(subset=["insnum"]).head(2)
# Out:
# There are 246 rows and 5 columns in  *wikipedia-iso-country-codes.csv*.
#   English short name lower case Alpha-2 code Alpha-3 code  Numeric code  \
# 0                      Zimbabwe           ZW          ZWE           716
# 1                        Zambia           ZM          ZMB           894
#
#       ISO 3166-2
# 0  ISO 3166-2:ZW
# 1  ISO 3166-2:ZM
#                  English short name lower case Alpha-2 code Alpha-3 code  \
# column type                             object       object       object
# null values (nb)                             0            1            0
# null values (%)                              0     0.406504            0
#
#                  Numeric code ISO 3166-2
# column type             int64     object
# null values (nb)            0          0
# null values (%)             0          0

# %% [markdown]
# ## US cities Demographics
# * us-cities-demographics.csv
# * There are 2891 rows and 12 columns in  *us-cities-demographics.csv*.
# * df_demograph

# %%
file = "us-cities-demographics.csv"
df = pd.read_csv(path+file, sep=";")
nRow, nCol = df.shape
print("There are {} rows and {} columns in  *{}*. ".format(nRow, nCol, file))

#display(df[pd.notnull(df).any(axis=1)].head(2))
display(df.head(2))
#display(df.dropna(subset=["iata_code"]).head(2))

tab_info=pd.DataFrame(df.dtypes).T.rename(index={0:'column type'})
tab_info=tab_info.append(pd.DataFrame(df.isnull().sum()).T.rename(index={0:'null values (nb)'}))
tab_info=tab_info.append(pd.DataFrame(df.isnull().sum()/df.shape[0]*100)
                         .T.rename(index={0:'null values (%)'}))
tab_info
#change subset
# Out:
# There are 2891 rows and 12 columns in  *us-cities-demographics.csv*.
#             City          State  Median Age  Male Population  \
# 0  Silver Spring       Maryland        33.8          40601.0
# 1         Quincy  Massachusetts        41.0          44129.0
#
#    Female Population  Total Population  Number of Veterans  Foreign-born  \
# 0            41862.0             82463              1562.0       30908.0
# 1            49500.0             93629              4147.0       32935.0
#
#    Average Household Size State Code                Race  Count
# 0                    2.60         MD  Hispanic or Latino  25924
# 1                    2.39         MA               White  58723
#                     City   State Median Age Male Population Female Population  \
# column type       object  object    float64         float64           float64
# null values (nb)       0       0          0               3                 3
# ...

# %% [markdown]
# ## World Development Indicators Data
# * WDIData.csv
# * There are 422136 rows and 64 columns in  *WDIData.csv*.
# * df_indicator_dev

# %%
file = "WDIData.csv"
df = pd.read_csv(path+file)
nRow, nCol = df.shape
print("There are {} rows and {} columns in  *{}*. ".format(nRow, nCol, file))

#display(df[pd.notnull(df).any(axis=1)].head(2))
display(df.head(2))
#display(df.dropna(subset=["iata_code"]).head(2))

tab_info=pd.DataFrame(df.dtypes).T.rename(index={0:'column type'})
tab_info=tab_info.append(pd.DataFrame(df.isnull().sum()).T.rename(index={0:'null values (nb)'}))
tab_info=tab_info.append(pd.DataFrame(df.isnull().sum()/df.shape[0]*100)
                         .T.rename(index={0:'null values (%)'}))
tab_info
#change subset
# Out:
# There are 422136 rows and 64 columns in  *WDIData.csv*.
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  2005 PPP conversion factor, GDP (LCU per inter...      PA.NUS.PPP.05   NaN
# 1  2005 PPP conversion factor, private consumptio...  PA.NUS.PRVT.PP.05   NaN
#
#    1961  1962  1963  1964  1965  1966  1967  1968  1969  1970  1971  1972  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    1973  1974  1975  1976  1977  1978  1979  1980  1981  1982  1983  1984  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    1985  1986  1987  1988  1989  1990  1991  1992  1993  1994  1995  1996  \
# ...

# %% [markdown]
# ## Education statistics Data
# * education-statistics/EdStatsData.csv
# * There are 886930 rows and 70 columns in  *education-statistics/EdStatsData.csv*.
# * df_Educ_data
# * Edit: i find some data in 'World Development Indicators Data' so I didn't use this dataset

# %%
file = "education-statistics/EdStatsData.csv"
df = pd.read_csv(path+file)
nRow, nCol = df.shape
print("There are {} rows and {} columns in  *{}*. ".format(nRow, nCol, file))

#display(df[pd.notnull(df).any(axis=1)].head(2))
display(df.head(2))
#display(df.dropna(subset=["iata_code"]).head(2))

tab_info=pd.DataFrame(df.dtypes).T.rename(index={0:'column type'})
tab_info=tab_info.append(pd.DataFrame(df.isnull().sum()).T.rename(index={0:'null values (nb)'}))
tab_info=tab_info.append(pd.DataFrame(df.isnull().sum()/df.shape[0]*100)
                         .T.rename(index={0:'null values (%)'}))
tab_info
# Out:
# There are 886930 rows and 70 columns in  *education-statistics/EdStatsData.csv*.
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
#
#                                       Indicator Name Indicator Code  1970  \
# 0  Adjusted net enrolment rate, lower secondary, ...     UIS.NERA.2   NaN
# 1  Adjusted net enrolment rate, lower secondary, ...   UIS.NERA.2.F   NaN
#
#    1971  1972  1973  1974  1975  1976  1977  1978  1979  1980  1981  1982  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    1983  1984  1985  1986  1987  1988  1989  1990  1991  1992  1993  1994  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    1995  1996  1997  1998  1999  2000  2001  2002  2003  2004  2005  2006  \
# ...

# %%
file = "i94addr.csv"
df = pd.read_csv(path+file)
nRow, nCol = df.shape
print("There are {} rows and {} columns in  *{}*. ".format(nRow, nCol, file))

#display(df[pd.notnull(df).any(axis=1)].head(2))
display(df.head(2))
#display(df.dropna(subset=["iata_code"]).head(2))

tab_info=pd.DataFrame(df.dtypes).T.rename(index={0:'column type'})
tab_info=tab_info.append(pd.DataFrame(df.isnull().sum()).T.rename(index={0:'null values (nb)'}))
tab_info=tab_info.append(pd.DataFrame(df.isnull().sum()/df.shape[0]*100)
                         .T.rename(index={0:'null values (%)'}))
tab_info
#change subset
# Out:
# There are 55 rows and 2 columns in  *i94addr.csv*.
#   State_id    State
# 0       Al  Alabama
# 1       Ak   Alaska
#                  State_id   State
# column type        object  object
# null values (nb)        0       0
# null values (%)         0       0

# %%
file = "i94mode.csv"
df = pd.read_csv(path+file)
nRow, nCol = df.shape
print("There are {} rows and {} columns in  *{}*. ".format(nRow, nCol, file))

#display(df[pd.notnull(df).any(axis=1)].head(2))
display(df.head(2))
#display(df.dropna(subset=["iata_code"]).head(2))

tab_info=pd.DataFrame(df.dtypes).T.rename(index={0:'column type'})
tab_info=tab_info.append(pd.DataFrame(df.isnull().sum()).T.rename(index={0:'null values (nb)'}))
tab_info=tab_info.append(pd.DataFrame(df.isnull().sum()/df.shape[0]*100)
                         .T.rename(index={0:'null values (%)'}))
tab_info
#change subset
# Out:
# There are 4 rows and 2 columns in  *i94mode.csv*.
#    Mode_id Mode
# 0        1  Air
# 1        2  Sea
#                  Mode_id    Mode
# column type        int64  object
# null values (nb)       0       0
# null values (%)        0       0

# %%
file = "i94port.csv"
df = pd.read_csv(path+file)
nRow, nCol = df.shape
print("There are {} rows and {} columns in  *{}*. ".format(nRow, nCol, file))

#display(df[pd.notnull(df).any(axis=1)].head(2))
display(df.head(2))
#display(df.dropna(subset=["iata_code"]).head(2))

tab_info=pd.DataFrame(df.dtypes).T.rename(index={0:'column type'})
tab_info=tab_info.append(pd.DataFrame(df.isnull().sum()).T.rename(index={0:'null values (nb)'}))
tab_info=tab_info.append(pd.DataFrame(df.isnull().sum()/df.shape[0]*100)
                         .T.rename(index={0:'null values (%)'}))
tab_info
#change subset
# Out:
# There are 583 rows and 3 columns in  *i94port.csv*.
#   Port_id  Port_city State_id
# 0     Alc      Alcan       Ak
# 1     Anc  Anchorage       Ak
#                  Port_id Port_city State_id
# column type       object    object   object
# null values (nb)       0         0        0
# null values (%)        0         0        0

# %%
file = "i94visa.csv"
df = pd.read_csv(path+file)
nRow, nCol = df.shape
print("There are {} rows and {} columns in  *{}*. ".format(nRow, nCol, file))

#display(df[pd.notnull(df).any(axis=1)].head(2))
display(df.head(2))
#display(df.dropna(subset=["iata_code"]).head(2))

tab_info=pd.DataFrame(df.dtypes).T.rename(index={0:'column type'})
tab_info=tab_info.append(pd.DataFrame(df.isnull().sum()).T.rename(index={0:'null values (nb)'}))
tab_info=tab_info.append(pd.DataFrame(df.isnull().sum()/df.shape[0]*100)
                         .T.rename(index={0:'null values (%)'}))
tab_info
#change subset
# Out:
# There are 3 rows and 2 columns in  *i94visa.csv*.
#    Code_visa      Visa
# 0          1  Business
# 1          2  Pleasure
#                  Code_visa    Visa
# column type          int64  object
# null values (nb)         0       0
# null values (%)          0       0
